# %%
# !mkdir -p unsloth_wheels
# !pip download unsloth torch accelerate -d unsloth_wheels


# !pip uninstall --yes torch accelerate
# !pip install --no-index --find-links=/kaggle/working/unsloth_wheels unsloth

# %%
install_dir = "/kaggle/working"
# !pip install --no-deps --target={install_dir} bitsandbytes
# !pip install --no-deps --target={install_dir} accelerate
# !pip install --no-deps --target={install_dir} xformers==0.0.29.post3
# !pip install --no-deps --target={install_dir} peft
# !pip install --no-deps --target={install_dir} trl
# !pip install --no-deps --target={install_dir} triton
# !pip install --no-deps --target={install_dir} cut_cross_entropy
# !pip install --no-deps --target={install_dir} unsloth_zoo
# !pip install --no-deps --target={install_dir} sentencepiece
# !pip install --no-deps --target={install_dir} protobuf
# !pip install --no-deps --target={install_dir} "datasets>=3.4.1"
# !pip install --no-deps --target={install_dir} huggingface_hub
# !pip install --no-deps --target={install_dir} hf_transfer
# !pip install --no-deps --target={install_dir} unsloth
# !pip install --no-deps --target={install_dir} git+https://github.com/huggingface/transformers.git
# !pip install --no-deps --upgrade --target={install_dir} timm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 367.1/367.1 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 MB 43.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.3/472.3 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.2/376.2 kB 7.3 MB/s eta 0:00:00
# ...
# WARNING: Target directory /kaggle/working/bin already exists. Specify --upgrade to force replacement.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 8.1 MB/s eta 0:00:00
# ...
# WARNING: Target directory /kaggle/working/bin already exists. Specify --upgrade to force replacement.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.7/164.7 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.1/321.1 kB 6.7 MB/s eta 0:00:00
# ...
